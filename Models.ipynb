# %%
import cv2 
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
train_x = torch.load('train_x.pt', map_location=torch.device('cpu'))
train_y = torch.load('train_y.pt', map_location=torch.device('cpu'))
test_x = torch.load('test_x.pt', map_location=torch.device('cpu'))
test_y = torch.load('test_y.pt', map_location=torch.device('cpu'))

# %%
print("train_x shape: ", train_x.size())
print("train_y shape: ", train_y.size())
print("test_x shape: ", test_x.size())
print("test_y shape: ", test_y.size())
# Out:
# train_x shape:  torch.Size([4170, 128, 128, 3])
# train_y shape:  torch.Size([4170])
# test_x shape:  torch.Size([1994, 128, 128, 3])
# test_y shape:  torch.Size([1994])

# %%
train_x = train_x.numpy().astype('float64')
train_y = train_y.numpy().astype('float64')
test_x = test_x.numpy().astype('float64')
test_y = test_y.numpy().astype('float64')

# %%
print("train_x shape: ", train_x.shape)
print("train_y shape: ", train_y.shape)
print("test_x shape: ", test_x.shape)
print("test_y shape: ", test_y.shape)
# Out:
# train_x shape:  (4170, 128, 128, 3)
# train_y shape:  (4170,)
# test_x shape:  (1994, 128, 128, 3)
# test_y shape:  (1994,)

# %%
idx = np.random.permutation(train_x.shape[0])
train_x_shuffle, train_y_shuffle = train_x[idx], train_y[idx]
idx = np.random.permutation(test_x.shape[0])
test_x_shuffle, test_y_shuffle = test_x[idx], test_y[idx]

# %%
np.swapaxes(train_x_shuffle,3,1)
np.swapaxes(test_x_shuffle,3,1)
# Out:
# array([[[[253., 253., 253., ..., 253., 254., 254.],
#          [253., 253., 253., ..., 254., 254., 254.],
#          [253., 253., 253., ..., 255., 255., 255.],
#          ...,
#          [252., 252., 252., ..., 179., 166., 161.],
#          [252., 252., 252., ..., 169., 161., 161.],
#          [253., 253., 253., ..., 166., 160., 165.]],
#
#         [[254., 254., 254., ..., 253., 254., 254.],
#          [253., 254., 254., ..., 253., 254., 254.],
#          [253., 253., 254., ..., 254., 254., 254.],
#          ...,
#          [252., 252., 252., ..., 178., 165., 160.],
#          [252., 252., 252., ..., 168., 160., 160.],
#          [253., 253., 253., ..., 165., 159., 164.]],
#
#         [[251., 251., 251., ..., 240., 241., 242.],
#          [251., 251., 251., ..., 241., 242., 242.],
#          [251., 251., 251., ..., 243., 242., 242.],
#          ...,
#          [252., 252., 252., ..., 173., 160., 155.],
#          [252., 252., 252., ..., 163., 155., 155.],
#          [253., 253., 253., ..., 160., 154., 159.]]],
#
#
#        [[[253., 253., 254., ..., 252., 250., 250.],
#          [253., 253., 254., ..., 252., 251., 250.],
#          [253., 254., 254., ..., 253., 252., 252.],
#          ...,
#          [255., 255., 255., ..., 204., 203., 202.],
#          [255., 255., 255., ..., 173., 170., 168.],
#          [255., 255., 255., ..., 167., 163., 162.]],
#
#         [[255., 255., 255., ..., 248., 246., 246.],
#          [255., 255., 255., ..., 248., 247., 247.],
#          [255., 255., 255., ..., 250., 250., 249.],
#          ...,
#          [255., 255., 255., ..., 210., 209., 208.],
#          [255., 255., 255., ..., 180., 178., 177.],
#          [255., 255., 255., ..., 175., 172., 171.]],
#
#         [[255., 255., 255., ..., 242., 240., 239.],
#          [255., 255., 255., ..., 242., 240., 240.],
#          [255., 255., 255., ..., 246., 245., 244.],
#          ...,
#          [255., 255., 255., ..., 197., 196., 196.],
#          [255., 255., 255., ..., 165., 162., 161.],
#          [255., 255., 255., ..., 159., 155., 154.]]],
#
#
#        [[[ 65.,  59.,  55., ..., 117., 106.,  96.],
#          [ 66.,  61.,  54., ...,  96., 100., 106.],
#          [ 68.,  63.,  55., ...,  74., 103., 130.],
#          ...,
#          [237., 239., 237., ..., 134., 134., 131.],
#          [237., 236., 232., ..., 139., 140., 142.],
#          [213., 211., 207., ..., 145., 148., 150.]],
#
#         [[ 74.,  69.,  64., ..., 126., 116., 106.],
#          [ 75.,  70.,  63., ..., 105., 110., 117.],
#          [ 77.,  72.,  64., ...,  84., 115., 142.],
#          ...,
#          [238., 240., 238., ..., 131., 129., 125.],
#          [237., 235., 231., ..., 131., 131., 132.],
#          [210., 208., 204., ..., 134., 136., 137.]],
#
#         [[ 69.,  63.,  59., ..., 111., 101.,  91.],
#          [ 70.,  65.,  58., ...,  91.,  95., 101.],
#          [ 72.,  67.,  59., ...,  70.,  99., 126.],
#          ...,
#          [229., 231., 232., ..., 118., 117., 112.],
#          [228., 226., 224., ..., 117., 117., 117.],
#          [201., 199., 197., ..., 119., 121., 122.]]],
#
#
#        ...,
#
#
#        [[[203., 204., 202., ..., 201., 201., 201.],
#          [203., 204., 203., ..., 199., 198., 198.],
#          [204., 205., 203., ..., 199., 198., 198.],
#          ...,
#          [201., 199., 197., ..., 207., 190., 159.],
#          [201., 198., 198., ..., 205., 184., 167.],
#          [200., 198., 198., ..., 194., 180., 177.]],
#
#         [[203., 204., 204., ..., 192., 192., 192.],
#          [203., 204., 205., ..., 192., 191., 191.],
#          [204., 205., 205., ..., 192., 191., 191.],
#          ...,
#          [202., 201., 200., ..., 208., 190., 160.],
#          [202., 200., 200., ..., 207., 186., 168.],
#          [201., 200., 200., ..., 196., 182., 180.]],
#
#         [[195., 196., 196., ..., 174., 174., 174.],
#          [195., 196., 197., ..., 174., 173., 173.],
#          [196., 197., 197., ..., 174., 173., 173.],
#          ...,
#          [190., 190., 191., ..., 200., 181., 149.],
#          [190., 190., 191., ..., 199., 177., 159.],
#          [189., 190., 191., ..., 187., 173., 170.]]],
#
#
#        [[[214., 214., 213., ...,  24.,   9.,  17.],
#          [214., 214., 213., ...,  35.,  24.,  29.],
#          [214., 214., 214., ...,  34.,  34.,  31.],
#          ...,
#          [ 33.,  31.,  19., ...,  13.,  13.,  15.],
#          [ 32.,  45.,  39., ...,  17.,  17.,  14.],
#          [ 33.,  44.,  38., ...,  16.,  17.,  19.]],
#
#         [[178., 178., 177., ...,  53.,  31.,  32.],
#          [178., 178., 177., ...,  40.,  28.,  34.],
#          [178., 178., 178., ...,  26.,  28.,  31.],
#          ...,
#          [ 49.,  46.,  35., ...,  21.,  21.,  23.],
#          [ 48.,  61.,  55., ...,  26.,  25.,  21.],
#          [ 49.,  60.,  54., ...,  29.,  30.,  26.]],
#
#         [[145., 145., 144., ...,  44.,  23.,  26.],
#          [145., 145., 144., ...,  36.,  24.,  30.],
#          [145., 145., 145., ...,  25.,  26.,  27.],
#          ...,
#          [ 41.,  38.,  27., ...,  19.,  19.,  21.],
#          [ 40.,  53.,  47., ...,  23.,  23.,  20.],
#          [ 41.,  52.,  46., ...,  22.,  23.,  24.]]],
#
#
#        [[[111., 171., 190., ..., 200., 202., 200.],
#          [109., 163., 180., ..., 118., 132., 147.],
#          [119., 174., 185., ...,  96., 118., 161.],
#          ...,
#          [142., 153., 142., ..., 102., 154., 183.],
#          [149., 177., 163., ..., 105., 130., 170.],
#          [118., 127., 116., ..., 122., 106., 154.]],
#
#         [[125., 174., 204., ..., 200., 200., 200.],
#          [121., 165., 194., ..., 115., 123., 142.],
#          [130., 178., 202., ...,  91., 113., 165.],
#          ...,
#          [148., 163., 165., ...,  96., 138., 179.],
#          [160., 189., 185., ..., 112., 119., 167.],
#          [125., 141., 134., ..., 141., 105., 152.]],
#
#         [[155., 177., 216., ..., 195., 194., 194.],
#          [153., 173., 208., ..., 112., 119., 135.],
#          [160., 186., 217., ...,  93., 113., 166.],
#          ...,
#          [168., 178., 189., ..., 113., 143., 177.],
#          [185., 209., 210., ..., 129., 122., 164.],
#          [147., 159., 163., ..., 155., 114., 148.]]]])
